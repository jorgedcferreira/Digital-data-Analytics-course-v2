# %%
import pandas as pd

# %%
dados = pd.read_csv('./data_set_EU.csv', encoding = "ISO-8859-1")
dados
# Out:
#              Paises  Rendimento Ensino basico  \
# 0          Alemanha                   18134.0
# 1           Austria                   21760.0
# 2           Belgica                   18431.0
# 3          Bulgaria                    2539.0
# 4            Chipre                   12430.0
# 5           Croacia                    4919.0
# 6         Dinamarca                   26758.0
# 7        Eslovaquia                    5841.0
# 8         Eslovenia                   10557.0
# 9           Espanha                   13052.0
# 10          Estónia                    7585.0
# 11        Finlandia                   21886.0
# 12           Franca                   22155.0
# 13           Grecia                    7152.0
# 14          Hungria                    4246.0
# 15          Irlanda                       NaN
# 16           Italia                   15621.0
# 17          Letonia                    5106.0
# 18         Lituania                    4763.0
# ...

# %%
dados.describe()
dados[['Moeda']].describe()
# Out:
#        Moeda
# count     28
# unique     2
# top     Euro
# freq      19

# %%
whiskers = 3 #
plot = dados[["Rendimento Ensino basico", "Rendimento Ensino pos-secundario", "Rendimento Ensino superior"]].boxplot(figsize=[30,15], whis=whiskers)

plot
